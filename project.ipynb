# %%
import pandas as pd
import numpy as np
import requests
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import csv

# %% [markdown]
# # Section 1: Zillow Housing Data

# %%
zhvi_3brm = pd.read_csv('zillow_data.csv')

# %%
zhvi_3brm.shape
# Out:
# (18458, 280)

# %%
zhvi_3brm.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
# 4      6915         4  San Antonio       city        TX    TX
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    244993.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    228623.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County     99808.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    160643.0
# 4          San Antonio-New Braunfels, TX        Bexar County    102255.0
#
#    2000-02-29  ...  2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# 0    246745.0  ...    708040.0    711549.0    715775.0    720637.0
# 1    228794.0  ...    893402.0    899121.0    904265.0    913104.0
# 2     99844.0  ...    227481.0    230208.0    233037.0    236333.0
# 3    160951.0  ...    304296.0    306968.0    309531.0    311054.0
# 4    102416.0  ...    241410.0    245654.0    249856.0    253847.0
#
#    2022-03-31  2022-04-30  2022-05-31  2022-06-30  2022-07-31  2022-08-31
# 0    726757.0    732698.0    739633.0    744904.0    749033.0    751137.0
# 1    928696.0    947698.0    964530.0    966200.0    965512.0    950327.0
# 2    240567.0    245106.0    249391.0    252562.0    254626.0    255900.0
# 3    313336.0    315071.0    318527.0    321029.0    322421.0    321973.0
# 4    258904.0    263939.0    268412.0    271147.0    272190.0    272533.0
#
# [5 rows x 280 columns]

# %%
for x in zhvi_3brm.columns[9:]:
    i = zhvi_3brm.columns.get_loc(x)
    if i+1>279:
        break
    else:
        zhvi_3brm.iloc[:,9] = zhvi_3brm.iloc[:,9].fillna(zhvi_3brm.iloc[:, i+1])
# Out:
# 2000-02-29
# 9
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        248333.0
# 1        229873.0
# 2         99688.0
# 3        161657.0
# 4        102485.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2000-03-31, Length: 18458, dtype: float64
# 2000-03-31
# 10
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        251316.0
# 1        231866.0
# 2         99752.0
# 3        162874.0
# 4        102633.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2000-04-30, Length: 18458, dtype: float64
# 2000-04-30
# 11
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        254128.0
# 1        234313.0
# 2         99761.0
# 3        164310.0
# 4        101836.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2000-05-31, Length: 18458, dtype: float64
# 2000-05-31
# 12
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        257086.0
# 1        236569.0
# 2        100004.0
# 3        165614.0
# 4        101046.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2000-06-30, Length: 18458, dtype: float64
# 2000-06-30
# 13
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        260090.0
# 1        238889.0
# 2        100173.0
# 3        167030.0
# 4        100233.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2000-07-31, Length: 18458, dtype: float64
# 2000-07-31
# 14
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        262655.0
# 1        241494.0
# 2        100472.0
# 3        168559.0
# 4        100326.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2000-08-31, Length: 18458, dtype: float64
# 2000-08-31
# 15
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        264992.0
# 1        243885.0
# 2        100857.0
# 3        170083.0
# 4        100390.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2000-09-30, Length: 18458, dtype: float64
# 2000-09-30
# 16
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        267609.0
# 1        245840.0
# 2        101167.0
# 3        171701.0
# 4        100442.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2000-10-31, Length: 18458, dtype: float64
# 2000-10-31
# 17
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        270870.0
# 1        247724.0
# 2        101725.0
# 3        173383.0
# 4        100393.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2000-11-30, Length: 18458, dtype: float64
# 2000-11-30
# 18
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        273791.0
# 1        249603.0
# 2        102266.0
# 3        174974.0
# 4        100342.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2000-12-31, Length: 18458, dtype: float64
# 2000-12-31
# 19
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        276620.0
# 1        250961.0
# 2        102524.0
# 3        176308.0
# 4        100239.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-01-31, Length: 18458, dtype: float64
# 2001-01-31
# 20
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        279182.0
# 1        252244.0
# 2        102557.0
# 3        177354.0
# 4        100084.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-02-28, Length: 18458, dtype: float64
# 2001-02-28
# 21
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        282286.0
# 1        253894.0
# 2        102194.0
# 3        178707.0
# 4         99894.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-03-31, Length: 18458, dtype: float64
# 2001-03-31
# 22
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        285361.0
# 1        256313.0
# 2        102097.0
# 3        180016.0
# 4         99725.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-04-30, Length: 18458, dtype: float64
# 2001-04-30
# 23
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        288045.0
# 1        258676.0
# 2        102142.0
# 3        181518.0
# 4         99616.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-05-31, Length: 18458, dtype: float64
# 2001-05-31
# 24
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        290642.0
# 1        261013.0
# 2        102347.0
# 3        182785.0
# 4         99548.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-06-30, Length: 18458, dtype: float64
# 2001-06-30
# 25
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        293096.0
# 1        263526.0
# 2        102536.0
# 3        184033.0
# 4         99510.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-07-31, Length: 18458, dtype: float64
# 2001-07-31
# 26
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        295935.0
# 1        266319.0
# 2        102444.0
# 3        185481.0
# 4         99504.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-08-31, Length: 18458, dtype: float64
# 2001-08-31
# 27
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        298345.0
# 1        268837.0
# 2        102600.0
# 3        187092.0
# 4         99423.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-09-30, Length: 18458, dtype: float64
# 2001-09-30
# 28
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        300759.0
# 1        271510.0
# 2        102802.0
# 3        188902.0
# 4         99348.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-10-31, Length: 18458, dtype: float64
# 2001-10-31
# 29
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        303715.0
# 1        273870.0
# 2        103073.0
# 3        190360.0
# 4         99235.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-11-30, Length: 18458, dtype: float64
# 2001-11-30
# 30
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        307204.0
# 1        276427.0
# 2        103207.0
# 3        191468.0
# 4         99189.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2001-12-31, Length: 18458, dtype: float64
# 2001-12-31
# 31
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        310979.0
# 1        278336.0
# 2        103388.0
# 3        192579.0
# 4         99196.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-01-31, Length: 18458, dtype: float64
# 2002-01-31
# 32
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        313789.0
# 1        280557.0
# 2        103671.0
# 3        193784.0
# 4         99309.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-02-28, Length: 18458, dtype: float64
# 2002-02-28
# 33
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        313596.0
# 1        283321.0
# 2        104265.0
# 3        195428.0
# 4         99582.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-03-31, Length: 18458, dtype: float64
# 2002-03-31
# 34
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        312874.0
# 1        286978.0
# 2        104924.0
# 3        196538.0
# 4         99984.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-04-30, Length: 18458, dtype: float64
# 2002-04-30
# 35
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0             NaN
# 1        291057.0
# 2        105526.0
# 3        197797.0
# 4        100365.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-05-31, Length: 18458, dtype: float64
# 2002-05-31
# 36
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        314864.0
# 1        295112.0
# 2        106009.0
# 3        198579.0
# 4        100675.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-06-30, Length: 18458, dtype: float64
# 2002-06-30
# 37
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        317444.0
# 1        300293.0
# 2        106467.0
# 3        200103.0
# 4        100940.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-07-31, Length: 18458, dtype: float64
# 2002-07-31
# 38
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        320786.0
# 1        305724.0
# 2        107028.0
# 3        201845.0
# 4        101304.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-08-31, Length: 18458, dtype: float64
# 2002-08-31
# 39
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        323901.0
# 1        311513.0
# 2        107501.0
# 3        203964.0
# 4        101692.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-09-30, Length: 18458, dtype: float64
# 2002-09-30
# 40
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        327130.0
# 1        316655.0
# 2        107856.0
# 3        205803.0
# 4        102067.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-10-31, Length: 18458, dtype: float64
# 2002-10-31
# 41
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        329321.0
# 1        321861.0
# 2        108120.0
# 3        207041.0
# 4        102520.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-11-30, Length: 18458, dtype: float64
# 2002-11-30
# 42
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        331525.0
# 1        326864.0
# 2        108327.0
# 3        208495.0
# 4        102836.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2002-12-31, Length: 18458, dtype: float64
# 2002-12-31
# 43
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        333733.0
# 1        330881.0
# 2        108662.0
# 3        209880.0
# 4        103011.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-01-31, Length: 18458, dtype: float64
# 2003-01-31
# 44
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        336800.0
# 1        334441.0
# 2        108941.0
# 3        211601.0
# 4        102984.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-02-28, Length: 18458, dtype: float64
# 2003-02-28
# 45
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        340676.0
# 1        338696.0
# 2        109343.0
# 3        213031.0
# 4        102970.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-03-31, Length: 18458, dtype: float64
# 2003-03-31
# 46
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        345036.0
# 1        343110.0
# 2        109602.0
# 3        214714.0
# 4        103094.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-04-30, Length: 18458, dtype: float64
# 2003-04-30
# 47
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        349448.0
# 1        348721.0
# 2        109857.0
# 3        215905.0
# 4        103351.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-05-31, Length: 18458, dtype: float64
# 2003-05-31
# 48
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        355868.0
# 1        353086.0
# 2        110030.0
# 3        217151.0
# 4        103722.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-06-30, Length: 18458, dtype: float64
# 2003-06-30
# 49
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        360893.0
# 1        359536.0
# 2        110248.0
# 3        218187.0
# 4        104082.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-07-31, Length: 18458, dtype: float64
# 2003-07-31
# 50
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        365816.0
# 1        366233.0
# 2        110492.0
# 3        219906.0
# 4        104438.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-08-31, Length: 18458, dtype: float64
# 2003-08-31
# 51
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        367912.0
# 1        373784.0
# 2        110630.0
# 3        221784.0
# 4        104765.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-09-30, Length: 18458, dtype: float64
# 2003-09-30
# 52
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        370834.0
# 1        379443.0
# 2        110805.0
# 3        223998.0
# 4        104963.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-10-31, Length: 18458, dtype: float64
# 2003-10-31
# 53
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        373533.0
# 1        384987.0
# 2        110925.0
# 3        225841.0
# 4        104917.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-11-30, Length: 18458, dtype: float64
# 2003-11-30
# 54
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        376359.0
# 1        390875.0
# 2        111148.0
# 3        227695.0
# 4        105015.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2003-12-31, Length: 18458, dtype: float64
# 2003-12-31
# 55
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        379839.0
# 1        397903.0
# 2        111548.0
# 3        229625.0
# 4        105897.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-01-31, Length: 18458, dtype: float64
# 2004-01-31
# 56
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        383127.0
# 1        404959.0
# 2        112620.0
# 3        231370.0
# 4             NaN
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-02-29, Length: 18458, dtype: float64
# 2004-02-29
# 57
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        386640.0
# 1        412311.0
# 2             NaN
# 3        232978.0
# 4        108935.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-03-31, Length: 18458, dtype: float64
# 2004-03-31
# 58
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        389451.0
# 1        421631.0
# 2        115732.0
# 3        234789.0
# 4        110254.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-04-30, Length: 18458, dtype: float64
# 2004-04-30
# 59
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        393049.0
# 1        433290.0
# 2        116960.0
# 3        237106.0
# 4        110971.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-05-31, Length: 18458, dtype: float64
# 2004-05-31
# 60
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        396755.0
# 1        444694.0
# 2        117102.0
# 3        239614.0
# 4        111968.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-06-30, Length: 18458, dtype: float64
# 2004-06-30
# 61
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        401365.0
# 1        454824.0
# 2        117958.0
# 3        241943.0
# 4        112595.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-07-31, Length: 18458, dtype: float64
# 2004-07-31
# 62
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        405256.0
# 1        464041.0
# 2        118355.0
# 3        244219.0
# 4        113048.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-08-31, Length: 18458, dtype: float64
# 2004-08-31
# 63
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        410263.0
# 1        475050.0
# 2        119163.0
# 3        246266.0
# 4        113904.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-09-30, Length: 18458, dtype: float64
# 2004-09-30
# 64
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        415557.0
# 1        485559.0
# 2        119688.0
# 3        248513.0
# 4        114494.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-10-31, Length: 18458, dtype: float64
# 2004-10-31
# 65
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        421754.0
# 1        492697.0
# 2        120268.0
# 3        250849.0
# 4        115378.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-11-30, Length: 18458, dtype: float64
# 2004-11-30
# 66
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        427246.0
# 1        498698.0
# 2        120983.0
# 3        253468.0
# 4        115713.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2004-12-31, Length: 18458, dtype: float64
# 2004-12-31
# 67
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        431428.0
# 1        503285.0
# 2        121640.0
# 3        255861.0
# 4        116100.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-01-31, Length: 18458, dtype: float64
# 2005-01-31
# 68
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        435847.0
# 1        511166.0
# 2        122320.0
# 3        258185.0
# 4        116531.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-02-28, Length: 18458, dtype: float64
# 2005-02-28
# 69
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        441165.0
# 1        518461.0
# 2        122761.0
# 3        260399.0
# 4        117030.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-03-31, Length: 18458, dtype: float64
# 2005-03-31
# 70
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        447856.0
# 1        526678.0
# 2        123112.0
# 3        262795.0
# 4        117576.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-04-30, Length: 18458, dtype: float64
# 2005-04-30
# 71
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        454234.0
# 1        533435.0
# 2        123160.0
# 3        265443.0
# 4        117962.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-05-31, Length: 18458, dtype: float64
# 2005-05-31
# 72
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        458823.0
# 1        541872.0
# 2        123305.0
# 3        268063.0
# 4        118192.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-06-30, Length: 18458, dtype: float64
# 2005-06-30
# 73
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        465373.0
# 1        551311.0
# 2        123279.0
# 3        270591.0
# 4        118250.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-07-31, Length: 18458, dtype: float64
# 2005-07-31
# 74
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        472137.0
# 1        561714.0
# 2        123144.0
# 3        272968.0
# 4        118326.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-08-31, Length: 18458, dtype: float64
# 2005-08-31
# 75
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        480291.0
# 1        571923.0
# 2        122895.0
# 3        275793.0
# 4        118541.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-09-30, Length: 18458, dtype: float64
# 2005-09-30
# 76
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        487604.0
# 1        583458.0
# 2        122637.0
# 3        278281.0
# 4        119037.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-10-31, Length: 18458, dtype: float64
# 2005-10-31
# 77
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        493507.0
# 1        591632.0
# 2        122767.0
# 3        280875.0
# 4        119367.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-11-30, Length: 18458, dtype: float64
# 2005-11-30
# 78
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        500437.0
# 1        598754.0
# 2        122735.0
# 3        283440.0
# 4        119716.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2005-12-31, Length: 18458, dtype: float64
# 2005-12-31
# 79
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        505870.0
# 1        604937.0
# 2        122783.0
# 3        286068.0
# 4        119962.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-01-31, Length: 18458, dtype: float64
# 2006-01-31
# 80
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        511694.0
# 1        610392.0
# 2        122565.0
# 3        288569.0
# 4        120418.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-02-28, Length: 18458, dtype: float64
# 2006-02-28
# 81
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        515151.0
# 1        616501.0
# 2        122684.0
# 3        290886.0
# 4        120877.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-03-31, Length: 18458, dtype: float64
# 2006-03-31
# 82
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        518503.0
# 1        620620.0
# 2        122863.0
# 3        292839.0
# 4        121341.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-04-30, Length: 18458, dtype: float64
# 2006-04-30
# 83
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        522840.0
# 1        626922.0
# 2        123456.0
# 3        294506.0
# 4        121950.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-05-31, Length: 18458, dtype: float64
# 2006-05-31
# 84
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        527256.0
# 1        631526.0
# 2        123878.0
# 3        295219.0
# 4        122721.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-06-30, Length: 18458, dtype: float64
# 2006-06-30
# 85
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        530453.0
# 1        634418.0
# 2        124372.0
# 3        296017.0
# 4        123664.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-07-31, Length: 18458, dtype: float64
# 2006-07-31
# 86
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        534089.0
# 1        636101.0
# 2        124749.0
# 3        296410.0
# 4        124523.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-08-31, Length: 18458, dtype: float64
# 2006-08-31
# 87
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        536119.0
# 1        633973.0
# 2        125244.0
# 3        296773.0
# 4        125455.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-09-30, Length: 18458, dtype: float64
# 2006-09-30
# 88
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        535567.0
# 1        633397.0
# 2        125866.0
# 3        296683.0
# 4        126390.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-10-31, Length: 18458, dtype: float64
# 2006-10-31
# 89
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        530518.0
# 1        633084.0
# 2        126233.0
# 3        296837.0
# 4        127488.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-11-30, Length: 18458, dtype: float64
# 2006-11-30
# 90
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        527104.0
# 1        635074.0
# 2        126678.0
# 3        297334.0
# 4        128657.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2006-12-31, Length: 18458, dtype: float64
# 2006-12-31
# 91
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        525966.0
# 1        635661.0
# 2        126755.0
# 3        298469.0
# 4        129426.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-01-31, Length: 18458, dtype: float64
# 2007-01-31
# 92
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        526541.0
# 1        635431.0
# 2        126619.0
# 3        299508.0
# 4        129650.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-02-28, Length: 18458, dtype: float64
# 2007-02-28
# 93
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        530479.0
# 1        633799.0
# 2        126309.0
# 3        300114.0
# 4        129652.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-03-31, Length: 18458, dtype: float64
# 2007-03-31
# 94
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        531874.0
# 1        633282.0
# 2        126459.0
# 3        299953.0
# 4        129892.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-04-30, Length: 18458, dtype: float64
# 2007-04-30
# 95
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        534491.0
# 1        630456.0
# 2        126895.0
# 3        299332.0
# 4        130896.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-05-31, Length: 18458, dtype: float64
# 2007-05-31
# 96
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        531102.0
# 1        627590.0
# 2        127561.0
# 3        298665.0
# 4        131971.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-06-30, Length: 18458, dtype: float64
# 2007-06-30
# 97
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        529396.0
# 1        622038.0
# 2        127878.0
# 3        297732.0
# 4        133067.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-07-31, Length: 18458, dtype: float64
# 2007-07-31
# 98
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        527941.0
# 1        616566.0
# 2        128306.0
# 3        297011.0
# 4        133804.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-08-31, Length: 18458, dtype: float64
# 2007-08-31
# 99
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        526841.0
# 1        610539.0
# 2        128540.0
# 3        295652.0
# 4        134438.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-09-30, Length: 18458, dtype: float64
# 2007-09-30
# 100
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        527566.0
# 1        603319.0
# 2        128801.0
# 3        294588.0
# 4        135083.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-10-31, Length: 18458, dtype: float64
# 2007-10-31
# 101
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        527331.0
# 1        596837.0
# 2        128938.0
# 3        293370.0
# 4        135598.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-11-30, Length: 18458, dtype: float64
# 2007-11-30
# 102
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        527969.0
# 1        589978.0
# 2        129100.0
# 3        291671.0
# 4        136112.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# 18456         NaN
# 18457         NaN
# Name: 2007-12-31, Length: 18458, dtype: float64
# 2007-12-31
# 103
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        527825.0
# 1        585596.0
# 2        128542.0
# 3        290539.0
# 4        135813.0
#            ...
# 18453         NaN
# 18454         NaN
# 18455         NaN
# ...
# 0        653319.0
# 1        699348.0
# 2        181169.0
# 3        258343.0
# 4        191198.0
#            ...
# 18453    323216.0
# 18454     74557.0
# 18455         NaN
# 18456    103223.0
# 18457    200420.0
# Name: 2020-01-31, Length: 18458, dtype: float64
# 2020-01-31
# 248
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        654984.0
# 1        707553.0
# 2        181435.0
# 3        259393.0
# 4        191385.0
#            ...
# 18453    324363.0
# 18454     74932.0
# 18455         NaN
# 18456    103339.0
# 18457    199500.0
# Name: 2020-02-29, Length: 18458, dtype: float64
# 2020-02-29
# 249
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        655718.0
# 1        715732.0
# 2        182295.0
# 3        260184.0
# 4        192293.0
#            ...
# 18453    325558.0
# 18454     75255.0
# 18455         NaN
# 18456    103352.0
# 18457    198646.0
# Name: 2020-03-31, Length: 18458, dtype: float64
# 2020-03-31
# 250
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        656113.0
# 1        722374.0
# 2        183645.0
# 3        260650.0
# 4        192204.0
#            ...
# 18453    327027.0
# 18454     75543.0
# 18455         NaN
# 18456    103155.0
# 18457    199102.0
# Name: 2020-04-30, Length: 18458, dtype: float64
# 2020-04-30
# 251
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        655856.0
# 1        720201.0
# 2        184524.0
# 3        260606.0
# 4        192251.0
#            ...
# 18453    328112.0
# 18454     75624.0
# 18455         NaN
# 18456    103020.0
# 18457    204715.0
# Name: 2020-05-31, Length: 18458, dtype: float64
# 2020-05-31
# 252
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        656781.0
# 1        717451.0
# 2        184949.0
# 3        260962.0
# 4        192057.0
#            ...
# 18453    328911.0
# 18454     75858.0
# 18455         NaN
# 18456    102941.0
# 18457    205700.0
# Name: 2020-06-30, Length: 18458, dtype: float64
# 2020-06-30
# 253
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        657562.0
# 1        720977.0
# 2        185342.0
# 3        262685.0
# 4        192865.0
#            ...
# 18453    329662.0
# 18454     75753.0
# 18455         NaN
# 18456    103207.0
# 18457    207000.0
# Name: 2020-07-31, Length: 18458, dtype: float64
# 2020-07-31
# 254
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        658899.0
# 1        731925.0
# 2        186210.0
# 3        265146.0
# 4        194071.0
#            ...
# 18453    330537.0
# 18454     75897.0
# 18455         NaN
# 18456    103258.0
# 18457    202467.0
# Name: 2020-08-31, Length: 18458, dtype: float64
# 2020-08-31
# 255
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        659891.0
# 1        745622.0
# 2        188157.0
# 3        269620.0
# 4        196126.0
#            ...
# 18453    331132.0
# 18454     75894.0
# 18455         NaN
# 18456    103336.0
# 18457    203062.0
# Name: 2020-09-30, Length: 18458, dtype: float64
# 2020-09-30
# 256
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        661725.0
# 1        757041.0
# 2        190320.0
# 3        273686.0
# 4        198506.0
#            ...
# 18453    332172.0
# 18454     76127.0
# 18455         NaN
# 18456    103223.0
# 18457    203025.0
# Name: 2020-10-31, Length: 18458, dtype: float64
# 2020-10-31
# 257
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        664807.0
# 1        764825.0
# 2        192692.0
# 3        276602.0
# 4        200632.0
#            ...
# 18453    334491.0
# 18454     76745.0
# 18455         NaN
# 18456    103747.0
# 18457    204444.0
# Name: 2020-11-30, Length: 18458, dtype: float64
# 2020-11-30
# 258
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        668398.0
# 1        769466.0
# 2        194727.0
# 3        278209.0
# 4        202316.0
#            ...
# 18453    337323.0
# 18454     77395.0
# 18455         NaN
# 18456    104288.0
# 18457    206382.0
# Name: 2020-12-31, Length: 18458, dtype: float64
# 2020-12-31
# 259
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        672168.0
# 1        772563.0
# 2        196685.0
# 3        278656.0
# 4        203992.0
#            ...
# 18453         NaN
# 18454     78435.0
# 18455     41898.0
# 18456    105707.0
# 18457    209059.0
# Name: 2021-01-31, Length: 18458, dtype: float64
# 2021-01-31
# 260
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        675062.0
# 1        780467.0
# 2        199047.0
# 3        281432.0
# 4        206302.0
#            ...
# 18453    351153.0
# 18454     79076.0
# 18455     43677.0
# 18456    106919.0
# 18457    211601.0
# Name: 2021-02-28, Length: 18458, dtype: float64
# 2021-02-28
# 261
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        677815.0
# 1        789362.0
# 2        200234.0
# 3        283598.0
# 4        208617.0
#            ...
# 18453    358618.0
# 18454     79883.0
# 18455     45220.0
# 18456    108287.0
# 18457    214546.0
# Name: 2021-03-31, Length: 18458, dtype: float64
# 2021-03-31
# 262
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        679515.0
# 1        802649.0
# 2        201889.0
# 3        287170.0
# 4        211804.0
#            ...
# 18453    363418.0
# 18454     80260.0
# 18455     46480.0
# 18456    109020.0
# 18457    217841.0
# Name: 2021-04-30, Length: 18458, dtype: float64
# 2021-04-30
# 263
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        682434.0
# 1        819772.0
# 2        203812.0
# 3        288400.0
# 4        215586.0
#            ...
# 18453    368143.0
# 18454     80775.0
# 18455     47288.0
# 18456    110038.0
# 18457    221589.0
# Name: 2021-05-31, Length: 18458, dtype: float64
# 2021-05-31
# 264
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        685680.0
# 1        840265.0
# 2        208013.0
# 3        290727.0
# 4        220891.0
#            ...
# 18453    374203.0
# 18454     80928.0
# 18455     47320.0
# 18456    110805.0
# 18457    220902.0
# Name: 2021-06-30, Length: 18458, dtype: float64
# 2021-06-30
# 265
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        689502.0
# 1        862724.0
# 2        212560.0
# 3        293303.0
# 4        225654.0
#            ...
# 18453    379774.0
# 18454     81459.0
# 18455     47459.0
# 18456    111551.0
# 18457    220253.0
# Name: 2021-07-31, Length: 18458, dtype: float64
# 2021-07-31
# 266
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        693328.0
# 1        876067.0
# 2        217600.0
# 3        296751.0
# 4        230884.0
#            ...
# 18453    385757.0
# 18454     81745.0
# 18455     47726.0
# 18456    112014.0
# 18457    219542.0
# Name: 2021-08-31, Length: 18458, dtype: float64
# 2021-08-31
# 267
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        698499.0
# 1        885709.0
# 2        221553.0
# 3        299124.0
# 4        234349.0
#            ...
# 18453    391014.0
# 18454     81894.0
# 18455     48354.0
# 18456    112842.0
# 18457    223597.0
# Name: 2021-09-30, Length: 18458, dtype: float64
# 2021-09-30
# 268
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        703779.0
# 1        888642.0
# 2        225056.0
# 3        301460.0
# 4        238126.0
#            ...
# 18453    395765.0
# 18454     81941.0
# 18455     48289.0
# 18456    113612.0
# 18457    226453.0
# Name: 2021-10-31, Length: 18458, dtype: float64
# 2021-10-31
# 269
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        708040.0
# 1        893402.0
# 2        227481.0
# 3        304296.0
# 4        241410.0
#            ...
# 18453    398782.0
# 18454     82441.0
# 18455     48128.0
# 18456    114350.0
# 18457    227969.0
# Name: 2021-11-30, Length: 18458, dtype: float64
# 2021-11-30
# 270
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        711549.0
# 1        899121.0
# 2        230208.0
# 3        306968.0
# 4        245654.0
#            ...
# 18453    405801.0
# 18454     84759.0
# 18455     48313.0
# 18456    115974.0
# 18457    229953.0
# Name: 2021-12-31, Length: 18458, dtype: float64
# 2021-12-31
# 271
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        715775.0
# 1        904265.0
# 2        233037.0
# 3        309531.0
# 4        249856.0
#            ...
# 18453    412561.0
# 18454     86923.0
# 18455     48611.0
# 18456    117680.0
# 18457    232018.0
# Name: 2022-01-31, Length: 18458, dtype: float64
# 2022-01-31
# 272
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        720637.0
# 1        913104.0
# 2        236333.0
# 3        311054.0
# 4        253847.0
#            ...
# 18453    418024.0
# 18454     89240.0
# 18455     49411.0
# 18456    119342.0
# 18457    235227.0
# Name: 2022-02-28, Length: 18458, dtype: float64
# 2022-02-28
# 273
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        726757.0
# 1        928696.0
# 2        240567.0
# 3        313336.0
# 4        258904.0
#            ...
# 18453    418935.0
# 18454     90303.0
# 18455     49967.0
# 18456    119656.0
# 18457    240510.0
# Name: 2022-03-31, Length: 18458, dtype: float64
# 2022-03-31
# 274
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        732698.0
# 1        947698.0
# 2        245106.0
# 3        315071.0
# 4        263939.0
#            ...
# 18453    419915.0
# 18454     91850.0
# 18455     50461.0
# 18456    119928.0
# 18457    245236.0
# Name: 2022-04-30, Length: 18458, dtype: float64
# 2022-04-30
# 275
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        739633.0
# 1        964530.0
# 2        249391.0
# 3        318527.0
# 4        268412.0
#            ...
# 18453    422149.0
# 18454     93754.0
# 18455     50301.0
# 18456    120193.0
# 18457    250691.0
# Name: 2022-05-31, Length: 18458, dtype: float64
# 2022-05-31
# 276
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        744904.0
# 1        966200.0
# 2        252562.0
# 3        321029.0
# 4        271147.0
#            ...
# 18453    429285.0
# 18454     95634.0
# 18455     50544.0
# 18456    120790.0
# 18457    254857.0
# Name: 2022-06-30, Length: 18458, dtype: float64
# 2022-06-30
# 277
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        749033.0
# 1        965512.0
# 2        254626.0
# 3        322421.0
# 4        272190.0
#            ...
# 18453    436945.0
# 18454     97448.0
# 18455     50662.0
# 18456    121338.0
# 18457    259695.0
# Name: 2022-07-31, Length: 18458, dtype: float64
# 2022-07-31
# 278
# 0        246745.0
# 1        228794.0
# 2         99844.0
# 3        160951.0
# 4        102416.0
#            ...
# 18453    195917.0
# 18454     60521.0
# 18455     41898.0
# 18456     79299.0
# 18457    124116.0
# Name: 2000-02-29, Length: 18458, dtype: float64
# 0        751137.0
# 1        950327.0
# 2        255900.0
# 3        321973.0
# 4        272533.0
#            ...
# 18453    444590.0
# 18454     98740.0
# 18455     51025.0
# 18456    121865.0
# 18457    264322.0
# Name: 2022-08-31, Length: 18458, dtype: float64
# 2022-08-31
# 279

# %%
zhvi_3brm.isnull().sum()
# Out:
# RegionID        0
# SizeRank        0
# RegionName      0
# RegionType      0
# StateName       0
#              ...
# 2022-04-30    258
# 2022-05-31    215
# 2022-06-30    153
# 2022-07-31     93
# 2022-08-31     12
# Length: 280, dtype: int64

# %%
zhvi_3brms = zhvi_3brm[['RegionID', 'RegionName', 'State', 'CountyName', '2000-01-31', '2022-08-31']]
zhvi_3brms = zhvi_3brms.rename(columns = {'2000-01-31':'year1', '2022-08-31':'year2'})

# %%
def percent_change(col1, col2):
    return (col2 - col1)/col1

# %%
zhvi_3brms['percent_change'] = zhvi_3brms.apply(lambda x: percent_change(x.year1, x.year2), axis=1)

# %%
zhvi_3brms['city'] = zhvi_3brms['RegionName'].apply(lambda row: row.rstrip('County'))

# %%
zhvi_3brms
# Out:
#        RegionID        RegionName State          CountyName     year1  \
# 0          6181          New York    NY       Queens County  244993.0
# 1         12447       Los Angeles    CA  Los Angeles County  228623.0
# 2         39051           Houston    TX       Harris County   99808.0
# 3         17426           Chicago    IL         Cook County  160643.0
# 4          6915       San Antonio    TX        Bexar County  102255.0
# ...         ...               ...   ...                 ...       ...
# 18453     47188    Poncha Springs    CO      Chaffee County       NaN
# 18454      6427           Parsons    WV       Tucker County       NaN
# 18455     52717            Junior    WV      Barbour County       NaN
# 18456     54589  Strawberry Point    IA      Clayton County       NaN
# 18457     22420     Medicine Park    OK     Comanche County       NaN
#
#           year2  percent_change
# 0      751137.0        2.065953
# 1      950327.0        3.156743
# 2      255900.0        1.563923
# 3      321973.0        1.004277
# 4      272533.0        1.665229
# ...         ...             ...
# 18453  444590.0             NaN
# 18454   98740.0             NaN
# 18455   51025.0             NaN
# 18456  121865.0             NaN
# 18457  264322.0             NaN
#
# [18458 rows x 7 columns]

# %% [markdown]
# # Section 2: Training & Testing

# %%
# https://www.businessinsider.com/most-miserable-cities-in-the-united-states-based-on-data-2019-9
bi_raw = pd.read_csv('training_cities.csv', header = 1)[['City', 'State', 'WEIGHTED Z-SCORE']].dropna()

# %%
bi_raw.head()
# Out:
#           City       State  WEIGHTED Z-SCORE
# 0         Gary     Indiana         -1.313482
# 1  Port Arthur       Texas         -1.262623
# 2      Detroit    Michigan         -1.223281
# 3      Passaic  New Jersey         -1.174955
# 4       Newark  New Jersey         -1.138656

# %%
bi_final = bi_raw.rename(columns = {'City': 'city', 'State':'state', 'WEIGHTED Z-SCORE': 'z'})

# %%
bi_raw
# Out:
#             city       state         z
# 0           Gary     Indiana -1.313482
# 1    Port Arthur       Texas -1.262623
# 2        Detroit    Michigan -1.223281
# 3        Passaic  New Jersey -1.174955
# 4         Newark  New Jersey -1.138656
# ..           ...         ...       ...
# 990         Kyle       Texas  2.197704
# 991       Frisco       Texas  2.454678
# 992   Little Elm       Texas  3.247657
# 993      Leander       Texas  3.930241
# 994     Herriman        Utah  4.125790
#
# [995 rows x 3 columns]

# %%
bi_final['label'] = bi_raw.apply(lambda row: 1 if row.z >= -0.057849734 else 0, axis = 1)
bi_final['city_state'] = bi_final[['city', 'state']].agg(' '.join, axis=1)

# %%
bi_final = bi_final[['city', 'state', 'city_state', 'z' ,'label']]

# %%
bi_final
# Out:
#             city       state          city_state         z  label
# 0           Gary     Indiana        Gary Indiana -1.313482      0
# 1    Port Arthur       Texas   Port Arthur Texas -1.262623      0
# 2        Detroit    Michigan    Detroit Michigan -1.223281      0
# 3        Passaic  New Jersey  Passaic New Jersey -1.174955      0
# 4         Newark  New Jersey   Newark New Jersey -1.138656      0
# ..           ...         ...                 ...       ...    ...
# 990         Kyle       Texas          Kyle Texas  2.197704      1
# 991       Frisco       Texas        Frisco Texas  2.454678      1
# 992   Little Elm       Texas    Little Elm Texas  3.247657      1
# 993      Leander       Texas       Leander Texas  3.930241      1
# 994     Herriman        Utah       Herriman Utah  4.125790      1
#
# [995 rows x 5 columns]

# %% [markdown]
# # Section 3: News API

# %%
def counter(string, counts):
    x = string.split()
    count = 0
    for i in x:
        if i in counts:
            count += 1
    return count

# %%
endpoint="https://newsapi.org/v2/everything"

# %%
positives = ['positive', 'good', 'forward-looking', 
             'productive', 'best', 'finest', 
            'first rate', 'perfect', 'terrific', 'leading', 'optimal', 
             'primo', 'first class', 'greatest']
negatives = ['negative', 'unproductive', 'impotent', 'useless', 
            'disadvantageous', 'unhelpful', 'doubtful', 'fruitless', 'bad', 
             'worst', 'inferior', 'incorrect', 'not right', 'unfavorable']

# %%
results = []


for x in bi_final['city_state'][50:100]:
    URLPost = {'apiKey':'9309e7598f994f3e9f2fc16858a4796c',
            'q':x} #Replace your with your own API key from https://newsapi.org/docs/get-started
    response=requests.get(endpoint, URLPost)
    jsontxt = response.json()
    try:
        if jsontxt['totalResults'] == 0:
            results.append(0)
            continue
        else:
            p = 0
            n = 0
            for i in range(0, 100):
                k = jsontxt['articles'][i]['description']
                p += counter(k, positives)
                n += counter(k, negatives)
            results.append(p/(n+p))
    except:
        results.append(0)
        continue
        
bi_final['score'] = results

# %%
bi_first_50 = bi_final.head(50)

# %% [markdown]
# # Section 4: Simple Neural Network

# %%
def activation_base(x):
    e = 2.718281828459045
    return 1/(1+e**(-x))

activation = np.vectorize(activation_base)

def z_1(x, w1, b1):
    return np.dot(x, w1) + b1


def z_2(z, w2, b2):
    return np.dot(z, w2) + b2

def network(x, w1, b1, w2, b2):
    z1 = z_1(x, w1, b1)
    h = activation(z1)
    z2 = z_2(h, w2, b2)
    yhat = activation(z2)
    return [yhat, z1, z2]

def loss(hat, y):
    return .5*(hat - y)**2
loss_vect = np.vectorize(loss)

def der_sig(x):
    return x*(1-x)
der_sig_vect = np.vectorize(der_sig)

def hat(hats, y):
    return (hats - y)

hat_vect = np.vectorize(hat)

def identity_values(size, x):
    #returns identity matrix of size size with 1's replaced by x values, x should be sizex1 
    return np.identity(size)*np.asarray(x)

def matrix_gb(z1, w2):
    #helper matrix for partial derivatives
    zt = z1.transpose()
    sig = der_sig_vect(activation(zt))
    final = w2.transpose().dot(sig)
    return final.transpose()

def matrix_red(hats, y, Z2):
    #helper matrix for partial derivatives
    yhat = hat_vect(hats, y)
    sigz = identity_values(Z2.shape[0], der_sig_vect(activation(Z2)))
    return identity_values(Z2.shape[0], sigz.dot(yhat))

def dW1(x, w1, gb, r, lr):
    xt = x.transpose()
    final = xt.dot(r.dot(gb))*lr
    return w1-final

def dW2(z1, r, LR, W2):
    h = activation(z1)
    i = np.sum(r.dot(h), axis = 0)
    final = LR*i.transpose()
    return W2-final

def dB(gb, r, LR, B):
    final = np.sum(r.dot(gb), axis = 0)*LR
    return B-final

def dC(r, LR, c):
    final = np.sum(r)*LR
    return c-final

# %%
def full_network(x, w1, b1, w2, b2, lr, y, epoc, report):
    k = 0
    results = network(x, w1, b1, w2, b2)
    l = loss_vect(results[0], y)
    print("result vector of epoc "+str(k)+ " is \n"+str(results[0]))
    print("Mean loss of epoc "+str(k)+ " is \n"+str(np.mean(l)))
    print("Total loss of epoc "+str(k)+ " is \n"+str(np.sum(l)))
    ml = [np.mean(l)]
    sl = [np.sum(l)]
    while k <= epoc:
        gb = matrix_gb(results[1], w2)
        #print("GB matrix at epoc "+str(k)+ " is \n"+ str(gb.shape))
        
        red = matrix_red(results[0], y, results[2])
        #print("red matrix at epoc "+str(k)+ " is \n"+ str(red.shape))
        
        w1 = dW1(x, w1, gb, red, lr)
        if k % report == 0:
            print("w1 matrix at epoc "+str(k)+ " is \n"+ str(w1))
        
        w2 = dW2(results[1], red, lr, w2)
        if k % report == 0:
            print("w2 matrix at epoc "+str(k)+ " is \n"+ str(w2))
        
        b1 = dB(gb, red, lr, b1)
        if k % report == 0:
            print("b1 matrix at epoc "+str(k)+ " is \n"+ str(b1))
        
        b2 = dC(red, lr, b2)
        if k % report == 0:
            print("c matrix at epoc "+str(k)+ " is \n"+ str(b2))
        
        results = network(x, w1, b1, w2, b2)
        
        l = loss_vect(results[0], y)
        if k % report == 0:
            print("result vector of epoc "+str(k)+ " is \n"+str(results[0]))
            print("loss vector of epoc "+str(k)+ " is \n"+str(l))
            print("Mean loss of epoc "+str(k)+ " is \n"+str(np.mean(l)))
            print("Total loss of epoc "+str(k)+ " is \n"+str(np.sum(l)))
        ml.append(np.mean(l))
        sl.append(np.sum(l))
        k += 1
    return [ml, sl, results[0]]

# %%
tester = bi_first_50[['city','city_state', 'z', 'score', 'label']]

# %%
tester.to_csv('tester.csv')

# %%
weight1 = np.random.rand(2, 2)
weight1.shape
weight2 = np.random.rand(2, 1)
bias1 = np.random.rand(1, 2)
bias2 = np.random.rand(1, 1)

# %%
print(x_train.shape)
print(weight1.shape)
print(weight2.shape)
print(bias1.shape)
print(bias2.shape)
print(y_train.shape)
# Out:
# (40, 2)
# (2, 2)
# (2, 1)
# (1, 2)
# (1, 1)
# (40, 1)

# %%
x = tester[['z', 'score',]]
y = tester['label']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
y_trainm = np.matrix(y_train.values.reshape(40,1))
x_trainm = np.matrix(x_train.values.reshape(40,2))

# %% [markdown]
# ### Section 4.1: Results

# %%
results = full_network(x_trainm, weight1, bias1, weight2, bias2, .1, y_trainm ,100, 10)
# Out:
# result vector of epoc 0 is
# [[0.63091002]
#  [0.6356906 ]
#  [0.63742201]
#  [0.63603677]
#  [0.62989272]
#  [0.63569934]
#  [0.63207627]
#  [0.63226571]
#  [0.63776898]
#  [0.63102458]
#  [0.63049659]
#  [0.63665352]
#  [0.63692819]
#  [0.63186514]
#  [0.63734908]
#  [0.63468053]
#  [0.63220996]
#  [0.63712745]
#  [0.63186512]
#  [0.63011153]
#  [0.63176693]
#  [0.63617092]
#  [0.63191839]
#  [0.62936611]
#  [0.63133499]
#  [0.63520246]
#  [0.63216105]
#  [0.63187371]
#  [0.63139888]
#  [0.63752826]
#  [0.63060645]
#  [0.63134911]
#  [0.63129499]
#  [0.63781217]
#  [0.63131522]
#  [0.63024971]
#  [0.6321567 ]
#  [0.63654525]
#  [0.63723476]
#  [0.63200812]]
# Mean loss of epoc 0 is
# 0.20062318366852558
# Total loss of epoc 0 is
# 8.024927346741023
# w1 matrix at epoc 0 is
# [[0.22491887 0.56788125]
#  [0.04295281 0.66361134]]
# w2 matrix at epoc 0 is
# [[ 0.50318058]
#  [-0.35779659]]
# b1 matrix at epoc 0 is
# [[-0.06785194  0.76356964]]
# c matrix at epoc 0 is
# [[-0.46160008]]
# result vector of epoc 0 is
# [[0.39107248]
#  [0.37977458]
#  [0.3787451 ]
#  [0.37955161]
#  [0.39199884]
#  [0.37976885]
#  [0.39003912]
#  [0.38987493]
#  [0.3785655 ]
#  [0.39096944]
#  [0.39144665]
#  [0.37917524]
#  [0.37901646]
#  [0.39022341]
#  [0.37878402]
#  [0.38047095]
#  [0.38992313]
#  [0.37890476]
#  [0.39022344]
#  [0.39179808]
#  [0.3903096 ]
#  [0.37946745]
#  [0.39017681]
#  [0.39248468]
#  [0.39069181]
#  [0.38010279]
#  [0.3899655 ]
#  [0.39021591]
#  [0.39063496]
#  [0.37868912]
#  [0.39134689]
#  [0.39067924]
#  [0.39072745]
#  [0.37854379]
#  [0.39070942]
#  [0.39167167]
#  [0.38996927]
#  [0.37923933]
#  [0.37884584]
#  [0.39009846]]
# loss vector of epoc 0 is
# [[0.07646884]
#  [0.07211436]
#  [0.07172393]
#  [0.07202971]
#  [0.07683155]
#  [0.07211219]
#  [0.07606526]
#  [0.07600123]
#  [0.07165592]
#  [0.07642855]
#  [0.07661524]
#  [0.07188693]
#  [0.07182674]
#  [0.07613716]
#  [0.07173867]
#  [0.07237907]
#  [0.07602002]
#  [0.07178441]
#  [0.07613716]
#  [0.07675287]
#  [0.07617079]
#  [0.07199777]
#  [0.07611897]
#  [0.07702211]
#  [0.07632005]
#  [0.07223907]
#  [0.07603654]
#  [0.07613423]
#  [0.07629784]
#  [0.07170273]
#  [0.07657619]
#  [0.07631513]
#  [0.07633397]
#  [0.0716477 ]
#  [0.07632693]
#  [0.07670335]
#  [0.07603802]
#  [0.07191124]
#  [0.07176208]
#  [0.0760884 ]]
# Mean loss of epoc 0 is
# 0.07456132300394777
# Total loss of epoc 0 is
# 2.982452920157911
# w1 matrix at epoc 10 is
# [[0.14619957 0.48916195]
#  [0.06480549 0.68546403]]
# w2 matrix at epoc 10 is
# [[ 0.01139138]
#  [-1.04867342]]
# b1 matrix at epoc 10 is
# [[0.01433689 0.84575847]]
# c matrix at epoc 10 is
# [[-1.58235577]]
# result vector of epoc 10 is
# [[0.10035984]
#  [0.08800775]
#  [0.08565475]
#  [0.08752143]
#  [0.10228735]
#  [0.08799538]
#  [0.09821617]
#  [0.09787495]
#  [0.08520708]
#  [0.10014607]
#  [0.10113693]
#  [0.08667462]
#  [0.08630561]
#  [0.09859878]
#  [0.08574986]
#  [0.08947209]
#  [0.09797515]
#  [0.08604104]
#  [0.09859883]
#  [0.10186844]
#  [0.09877761]
#  [0.08733509]
#  [0.09850205]
#  [0.10330489]
#  [0.09957028]
#  [0.08870702]
#  [0.09806321]
#  [0.09858321]
#  [0.09945239]
#  [0.08551681]
#  [0.10092959]
#  [0.09954421]
#  [0.09964418]
#  [0.0851519 ]
#  [0.0996068 ]
#  [0.1016051 ]
#  [0.09807105]
#  [0.08682145]
#  [0.08589964]
#  [0.0983394 ]]
# loss vector of epoc 10 is
# [[0.00503605]
#  [0.00387268]
#  [0.00366837]
#  [0.00383   ]
#  [0.00523135]
#  [0.00387159]
#  [0.00482321]
#  [0.00478975]
#  [0.00363012]
#  [0.00501462]
#  [0.00511434]
#  [0.00375625]
#  [0.00372433]
#  [0.00486086]
#  [0.00367652]
#  [0.00400263]
#  [0.00479957]
#  [0.00370153]
#  [0.00486086]
#  [0.00518859]
#  [0.00487851]
#  [0.00381371]
#  [0.00485133]
#  [0.00533595]
#  [0.00495712]
#  [0.00393447]
#  [0.0048082 ]
#  [0.00485932]
#  [0.00494539]
#  [0.00365656]
#  [0.00509339]
#  [0.00495452]
#  [0.00496448]
#  [0.00362542]
#  [0.00496076]
#  [0.0051618 ]
#  [0.00480897]
#  [0.00376898]
#  [0.00368937]
#  [0.00483532]]
# Mean loss of epoc 10 is
# 0.004483919661791048
# Total loss of epoc 10 is
# 0.1793567864716419
# w1 matrix at epoc 20 is
# [[0.08985739 0.43281977]
#  [0.08150537 0.70216391]]
# w2 matrix at epoc 20 is
# [[-0.10066035]
#  [-1.19940074]]
# b1 matrix at epoc 20 is
# [[0.07328476 0.90470634]]
# c matrix at epoc 20 is
# [[-1.81251948]]
# result vector of epoc 20 is
# [[0.06911241]
#  [0.05912392]
#  [0.05753612]
#  [0.05879606]
#  [0.07050242]
#  [0.05911558]
#  [0.0675723 ]
#  [0.06732761]
#  [0.05723343]
#  [0.06895858]
#  [0.06967215]
#  [0.05822487]
#  [0.05797578]
#  [0.06784681]
#  [0.0576004 ]
#  [0.06011069]
#  [0.06739946]
#  [0.05779712]
#  [0.06784684]
#  [0.07019985]
#  [0.06797517]
#  [0.05867041]
#  [0.0677774 ]
#  [0.07123861]
#  [0.06854453]
#  [0.05959518]
#  [0.0674626 ]
#  [0.06783564]
#  [0.06845981]
#  [0.05744289]
#  [0.06952272]
#  [0.06852579]
#  [0.06859765]
#  [0.05719611]
#  [0.06857078]
#  [0.07000978]
#  [0.06746822]
#  [0.05832394]
#  [0.0577016 ]
#  [0.0676607 ]]
# loss vector of epoc 20 is
# [[0.00238826]
#  [0.00174782]
#  [0.0016552 ]
#  [0.00172849]
#  [0.0024853 ]
#  [0.00174733]
#  [0.00228301]
#  [0.0022665 ]
#  [0.00163783]
#  [0.00237764]
#  [0.0024271 ]
#  [0.00169507]
#  [0.0016806 ]
#  [0.0023016 ]
#  [0.0016589 ]
#  [0.00180665]
#  [0.00227134]
#  [0.00167025]
#  [0.0023016 ]
#  [0.00246401]
#  [0.00231031]
#  [0.00172111]
#  [0.00229689]
#  [0.00253747]
#  [0.00234918]
#  [0.00177579]
#  [0.0022756 ]
#  [0.00230084]
#  [0.00234337]
#  [0.00164984]
#  [0.0024167 ]
#  [0.00234789]
#  [0.00235282]
#  [0.0016357 ]
#  [0.00235098]
#  [0.00245068]
#  [0.00227598]
#  [0.00170084]
#  [0.00166474]
#  [0.00228899]]
# Mean loss of epoc 20 is
# 0.0020910053811380273
# Total loss of epoc 20 is
# 0.0836402152455211
# w1 matrix at epoc 30 is
# [[0.05357226 0.39653464]
#  [0.09185454 0.71251308]]
# w2 matrix at epoc 30 is
# [[-0.16590337]
#  [-1.28548744]]
# b1 matrix at epoc 30 is
# [[0.11127067 0.94269225]]
# c matrix at epoc 30 is
# [[-1.93998114]]
# result vector of epoc 30 is
# [[0.05526734]
#  [0.04663754]
#  [0.04544545]
#  [0.04639169]
#  [0.05635566]
#  [0.04663129]
#  [0.05406254]
#  [0.05387118]
#  [0.04521772]
#  [0.05514696]
#  [0.05570545]
#  [0.04596301]
#  [0.04577593]
#  [0.05427723]
#  [0.04549378]
#  [0.04737681]
#  [0.05392737]
#  [0.04564167]
#  [0.05427726]
#  [0.05611866]
#  [0.05437763]
#  [0.04629743]
#  [0.05422294]
#  [0.0569326 ]
#  [0.054823  ]
#  [0.04699072]
#  [0.05397675]
#  [0.05426849]
#  [0.05475672]
#  [0.04537532]
#  [0.05558847]
#  [0.05480834]
#  [0.05486456]
#  [0.04518963]
#  [0.05484354]
#  [0.05596981]
#  [0.05398114]
#  [0.0460374 ]
#  [0.04556987]
#  [0.05413167]]
# loss vector of epoc 30 is
# [[0.00152724]
#  [0.00108753]
#  [0.00103264]
#  [0.00107609]
#  [0.00158798]
#  [0.00108724]
#  [0.00146138]
#  [0.00145105]
#  [0.00102232]
#  [0.00152059]
#  [0.00155155]
#  [0.0010563 ]
#  [0.00104772]
#  [0.00147301]
#  [0.00103484]
#  [0.00112228]
#  [0.00145408]
#  [0.00104158]
#  [0.00147301]
#  [0.00157465]
#  [0.00147846]
#  [0.00107173]
#  [0.00147006]
#  [0.00162066]
#  [0.00150278]
#  [0.00110406]
#  [0.00145674]
#  [0.00147253]
#  [0.00149915]
#  [0.00102946]
#  [0.00154504]
#  [0.00150198]
#  [0.00150506]
#  [0.00102105]
#  [0.00150391]
#  [0.00156631]
#  [0.00145698]
#  [0.00105972]
#  [0.00103831]
#  [0.00146512]]
# Mean loss of epoc 30 is
# 0.0013263053638281443
# Total loss of epoc 30 is
# 0.053052214553125775
# w1 matrix at epoc 40 is
# [[0.02684994 0.36981232]
#  [0.09929473 0.71995326]]
# w2 matrix at epoc 40 is
# [[-0.21186595]
#  [-1.34539137]]
# b1 matrix at epoc 40 is
# [[0.1392609  0.97068248]]
# c matrix at epoc 40 is
# [[-2.02694319]]
# result vector of epoc 40 is
# [[0.04710398]
#  [0.03938635]
#  [0.03843752]
#  [0.03919089]
#  [0.04799784]
#  [0.03938139]
#  [0.04611445]
#  [0.04595725]
#  [0.03825593]
#  [0.04700512]
#  [0.0474638 ]
#  [0.03884981]
#  [0.03870084]
#  [0.0462908 ]
#  [0.03847605]
#  [0.03997354]
#  [0.04600341]
#  [0.0385939 ]
#  [0.04629082]
#  [0.04780317]
#  [0.04637326]
#  [0.03911592]
#  [0.0462462 ]
#  [0.04847177]
#  [0.04673906]
#  [0.03966698]
#  [0.04604397]
#  [0.04628362]
#  [0.04668462]
#  [0.03838161]
#  [0.04736772]
#  [0.04672702]
#  [0.04677319]
#  [0.03823352]
#  [0.04675592]
#  [0.04768091]
#  [0.04604758]
#  [0.03890902]
#  [0.03853669]
#  [0.04617123]]
# loss vector of epoc 40 is
# [[0.00110939]
#  [0.00077564]
#  [0.00073872]
#  [0.00076796]
#  [0.0011519 ]
#  [0.00077545]
#  [0.00106327]
#  [0.00105603]
#  [0.00073176]
#  [0.00110474]
#  [0.00112641]
#  [0.00075465]
#  [0.00074888]
#  [0.00107142]
#  [0.0007402 ]
#  [0.00079894]
#  [0.00105816]
#  [0.00074474]
#  [0.00107142]
#  [0.00114257]
#  [0.00107524]
#  [0.00076503]
#  [0.00106936]
#  [0.00117476]
#  [0.00109227]
#  [0.00078673]
#  [0.00106002]
#  [0.00107109]
#  [0.00108973]
#  [0.00073657]
#  [0.00112185]
#  [0.00109171]
#  [0.00109387]
#  [0.0007309 ]
#  [0.00109306]
#  [0.00113673]
#  [0.00106019]
#  [0.00075696]
#  [0.00074254]
#  [0.00106589]]
# Mean loss of epoc 40 is
# 0.0009586687076727802
# Total loss of epoc 40 is
# 0.038346748306911205
# w1 matrix at epoc 50 is
# [[0.0057259  0.34868828]
#  [0.10507583 0.72573436]]
# w2 matrix at epoc 50 is
# [[-0.24729023]
#  [-1.39114609]]
# b1 matrix at epoc 50 is
# [[0.161398   0.99281959]]
# c matrix at epoc 50 is
# [[-2.09241533]]
# result vector of epoc 50 is
# [[0.0415968 ]
#  [0.03454756]
#  [0.03376443]
#  [0.03438639]
#  [0.04235372]
#  [0.03454347]
#  [0.04075855]
#  [0.04062535]
#  [0.03361432]
#  [0.04151307]
#  [0.04190151]
#  [0.03410496]
#  [0.03398197]
#  [0.04090798]
#  [0.03379627]
#  [0.03503131]
#  [0.04066446]
#  [0.03389364]
#  [0.04090799]
#  [0.04218889]
#  [0.04097784]
#  [0.03432455]
#  [0.04087019]
#  [0.042755  ]
#  [0.04128772]
#  [0.03477883]
#  [0.04069883]
#  [0.04090189]
#  [0.04124161]
#  [0.03371822]
#  [0.04182016]
#  [0.04127752]
#  [0.04131663]
#  [0.03359579]
#  [0.041302  ]
#  [0.04208537]
#  [0.04070189]
#  [0.03415384]
#  [0.03384638]
#  [0.04080667]]
# loss vector of epoc 50 is
# [[0.00086515]
#  [0.00059677]
#  [0.00057002]
#  [0.00059121]
#  [0.00089692]
#  [0.00059663]
#  [0.00083063]
#  [0.00082521]
#  [0.00056496]
#  [0.00086167]
#  [0.00087787]
#  [0.00058157]
#  [0.00057739]
#  [0.00083673]
#  [0.00057109]
#  [0.0006136 ]
#  [0.0008268 ]
#  [0.00057439]
#  [0.00083673]
#  [0.00088995]
#  [0.00083959]
#  [0.00058909]
#  [0.00083519]
#  [0.000914  ]
#  [0.00085234]
#  [0.00060478]
#  [0.0008282 ]
#  [0.00083648]
#  [0.00085044]
#  [0.00056846]
#  [0.00087446]
#  [0.00085192]
#  [0.00085353]
#  [0.00056434]
#  [0.00085293]
#  [0.00088559]
#  [0.00082832]
#  [0.00058324]
#  [0.00057279]
#  [0.00083259]]
# Mean loss of epoc 50 is
# 0.0007450886701953639
# Total loss of epoc 50 is
# 0.02980354680781456
# w1 matrix at epoc 60 is
# [[-0.01172222  0.33124017]
#  [ 0.10978823  0.73044676]]
# w2 matrix at epoc 60 is
# [[-0.27607557]
#  [-1.42806367]]
# b1 matrix at epoc 60 is
# [[0.1796908  1.01111238]]
# c matrix at epoc 60 is
# [[-2.14465034]]
# result vector of epoc 60 is
# [[0.03757453]
#  [0.03104309]
#  [0.03038056]
#  [0.03090685]
#  [0.03822921]
#  [0.03103963]
#  [0.03684913]
#  [0.03673382]
#  [0.03025339]
#  [0.03750209]
#  [0.03783812]
#  [0.03066882]
#  [0.03056474]
#  [0.03697847]
#  [0.03040753]
#  [0.03145168]
#  [0.03676768]
#  [0.03048997]
#  [0.03697849]
#  [0.03808667]
#  [0.03703894]
#  [0.03085457]
#  [0.03694577]
#  [0.03857621]
#  [0.03730711]
#  [0.03123848]
#  [0.03679744]
#  [0.03697321]
#  [0.03726721]
#  [0.03034142]
#  [0.03776774]
#  [0.03729828]
#  [0.03733213]
#  [0.03023769]
#  [0.03731947]
#  [0.03799714]
#  [0.03680008]
#  [0.03071018]
#  [0.03044995]
#  [0.03689079]]
# loss vector of epoc 60 is
# [[0.00070592]
#  [0.00048184]
#  [0.00046149]
#  [0.00047762]
#  [0.00073074]
#  [0.00048173]
#  [0.00067893]
#  [0.00067469]
#  [0.00045763]
#  [0.0007032 ]
#  [0.00071586]
#  [0.00047029]
#  [0.0004671 ]
#  [0.0006837 ]
#  [0.00046231]
#  [0.0004946 ]
#  [0.00067593]
#  [0.00046482]
#  [0.0006837 ]
#  [0.0007253 ]
#  [0.00068594]
#  [0.000476  ]
#  [0.00068249]
#  [0.00074406]
#  [0.00069591]
#  [0.00048792]
#  [0.00067703]
#  [0.00068351]
#  [0.00069442]
#  [0.0004603 ]
#  [0.0007132 ]
#  [0.00069558]
#  [0.00069684]
#  [0.00045716]
#  [0.00069637]
#  [0.00072189]
#  [0.00067712]
#  [0.00047156]
#  [0.0004636 ]
#  [0.00068047]]
# Mean loss of epoc 60 is
# 0.0006064696918949308
# Total loss of epoc 60 is
# 0.02425878767579723
# w1 matrix at epoc 70 is
# [[-0.02657232  0.31639006]
#  [ 0.11375656  0.73441509]]
# w2 matrix at epoc 70 is
# [[-0.30029866]
#  [-1.45895047]]
# b1 matrix at epoc 70 is
# [[0.19526586 1.02668745]]
# c matrix at epoc 70 is
# [[-2.1879519]]
# result vector of epoc 70 is
# [[0.0344782 ]
#  [0.02836367]
#  [0.02779307]
#  [0.02824641]
#  [0.03505334]
#  [0.02836069]
#  [0.03384059]
#  [0.03373919]
#  [0.02768342]
#  [0.03441455]
#  [0.03470979]
#  [0.02804146]
#  [0.0279518 ]
#  [0.03395431]
#  [0.02781631]
#  [0.02871507]
#  [0.03376897]
#  [0.02788737]
#  [0.03395433]
#  [0.03492813]
#  [0.03400747]
#  [0.0282014 ]
#  [0.03392556]
#  [0.03535808]
#  [0.03424319]
#  [0.02853175]
#  [0.03379514]
#  [0.03394968]
#  [0.03420812]
#  [0.02775933]
#  [0.03464797]
#  [0.03423544]
#  [0.03426518]
#  [0.02766988]
#  [0.03425406]
#  [0.03484949]
#  [0.03379747]
#  [0.02807708]
#  [0.02785288]
#  [0.03387722]]
# loss vector of epoc 70 is
# [[0.00059437]
#  [0.00040225]
#  [0.00038623]
#  [0.00039893]
#  [0.00061437]
#  [0.00040216]
#  [0.00057259]
#  [0.00056917]
#  [0.00038319]
#  [0.00059218]
#  [0.00060238]
#  [0.00039316]
#  [0.00039065]
#  [0.00057645]
#  [0.00038687]
#  [0.00041228]
#  [0.00057017]
#  [0.00038885]
#  [0.00057645]
#  [0.00060999]
#  [0.00057825]
#  [0.00039766]
#  [0.00057547]
#  [0.0006251 ]
#  [0.0005863 ]
#  [0.00040703]
#  [0.00057106]
#  [0.00057629]
#  [0.0005851 ]
#  [0.00038529]
#  [0.00060024]
#  [0.00058603]
#  [0.00058705]
#  [0.00038281]
#  [0.00058667]
#  [0.00060724]
#  [0.00057113]
#  [0.00039416]
#  [0.00038789]
#  [0.00057383]]
# Mean loss of epoc 70 is
# 0.0005096827183910032
# Total loss of epoc 70 is
# 0.020387308735640125
# w1 matrix at epoc 80 is
# [[-0.03948945  0.30347293]
#  [ 0.11717803  0.73783656]]
# w2 matrix at epoc 80 is
# [[-0.32119588]
#  [-1.48546629]]
# b1 matrix at epoc 80 is
# [[0.20881836 1.04023994]]
# c matrix at epoc 80 is
# [[-2.22483854]]
# result vector of epoc 80 is
# [[0.03200371]
#  [0.02623448]
#  [0.0257364 ]
#  [0.02613219]
#  [0.03251501]
#  [0.02623188]
#  [0.03143656]
#  [0.03134632]
#  [0.0256406 ]
#  [0.03194711]
#  [0.03220963]
#  [0.02595332]
#  [0.02587503]
#  [0.03153774]
#  [0.0257567 ]
#  [0.02654086]
#  [0.03137282]
#  [0.02581876]
#  [0.03153775]
#  [0.03240372]
#  [0.03158503]
#  [0.02609292]
#  [0.03151216]
#  [0.03278584]
#  [0.03179471]
#  [0.02638106]
#  [0.03139611]
#  [0.03153362]
#  [0.03176352]
#  [0.02570692]
#  [0.03215466]
#  [0.03178781]
#  [0.03181427]
#  [0.02562876]
#  [0.03180438]
#  [0.03233382]
#  [0.03139818]
#  [0.02598441]
#  [0.02578864]
#  [0.03146914]]
# loss vector of epoc 80 is
# [[0.00051212]
#  [0.00034412]
#  [0.00033118]
#  [0.00034145]
#  [0.00052861]
#  [0.00034406]
#  [0.00049413]
#  [0.0004913 ]
#  [0.00032872]
#  [0.00051031]
#  [0.00051873]
#  [0.00033679]
#  [0.00033476]
#  [0.00049731]
#  [0.0003317 ]
#  [0.00035221]
#  [0.00049213]
#  [0.0003333 ]
#  [0.00049731]
#  [0.000525  ]
#  [0.00049881]
#  [0.00034042]
#  [0.00049651]
#  [0.00053746]
#  [0.00050545]
#  [0.00034798]
#  [0.00049286]
#  [0.00049718]
#  [0.00050446]
#  [0.00033042]
#  [0.00051696]
#  [0.00050523]
#  [0.00050607]
#  [0.00032842]
#  [0.00050576]
#  [0.00052274]
#  [0.00049292]
#  [0.00033759]
#  [0.00033253]
#  [0.00049515]]
# Mean loss of epoc 80 is
# 0.00043850423929698125
# Total loss of epoc 80 is
# 0.01754016957187925
# w1 matrix at epoc 90 is
# [[-0.05091275  0.29204963]
#  [ 0.12018121  0.74083975]]
# w2 matrix at epoc 90 is
# [[-0.33956242]
#  [-1.50867269]]
# b1 matrix at epoc 90 is
# [[0.22080739 1.05222897]]
# c matrix at epoc 90 is
# [[-2.25690665]]
# result vector of epoc 90 is
# [[0.02996992]
#  [0.02449295]
#  [0.02405359]
#  [0.02440277]
#  [0.03042876]
#  [0.02449066]
#  [0.02946068]
#  [0.02937963]
#  [0.02396902]
#  [0.02991911]
#  [0.03015473]
#  [0.02424501]
#  [0.02417594]
#  [0.02955155]
#  [0.02407152]
#  [0.02476295]
#  [0.02940343]
#  [0.02412629]
#  [0.02955157]
#  [0.03032891]
#  [0.02959403]
#  [0.02436814]
#  [0.02952858]
#  [0.03067171]
#  [0.0297823 ]
#  [0.02462215]
#  [0.02942435]
#  [0.02954786]
#  [0.0297543 ]
#  [0.02402757]
#  [0.0301054 ]
#  [0.02977611]
#  [0.02979986]
#  [0.02395857]
#  [0.02979098]
#  [0.03026618]
#  [0.02942621]
#  [0.02427243]
#  [0.02409971]
#  [0.02948995]]
# loss vector of epoc 90 is
# [[0.0004491 ]
#  [0.00029995]
#  [0.00028929]
#  [0.00029775]
#  [0.00046295]
#  [0.0002999 ]
#  [0.00043397]
#  [0.00043158]
#  [0.00028726]
#  [0.00044758]
#  [0.00045465]
#  [0.00029391]
#  [0.00029224]
#  [0.00043665]
#  [0.00028972]
#  [0.0003066 ]
#  [0.00043228]
#  [0.00029104]
#  [0.00043665]
#  [0.00045992]
#  [0.0004379 ]
#  [0.0002969 ]
#  [0.00043597]
#  [0.00047038]
#  [0.00044349]
#  [0.00030313]
#  [0.0004329 ]
#  [0.00043654]
#  [0.00044266]
#  [0.00028866]
#  [0.00045317]
#  [0.00044331]
#  [0.00044402]
#  [0.00028701]
#  [0.00044375]
#  [0.00045802]
#  [0.00043295]
#  [0.00029458]
#  [0.0002904 ]
#  [0.00043483]]
# Mean loss of epoc 90 is
# 0.0003840881211192072
# Total loss of epoc 90 is
# 0.015363524844768288
# w1 matrix at epoc 100 is
# [[-0.06114735  0.28181503]
#  [ 0.12285447  0.74351301]]
# w2 matrix at epoc 100 is
# [[-0.35593963]
#  [-1.52928888]]
# b1 matrix at epoc 100 is
# [[0.23155203 1.06297361]]
# c matrix at epoc 100 is
# [[-2.28522939]]
# result vector of epoc 100 is
# [[0.02826149]
#  [0.02303618]
#  [0.02264537]
#  [0.022956  ]
#  [0.02867638]
#  [0.02303415]
#  [0.02780078]
#  [0.02772743]
#  [0.0225701 ]
#  [0.02821553]
#  [0.02842863]
#  [0.02281569]
#  [0.02275424]
#  [0.02788302]
#  [0.02266132]
#  [0.02327614]
#  [0.02774897]
#  [0.02271007]
#  [0.02788302]
#  [0.02858611]
#  [0.02792145]
#  [0.0229252 ]
#  [0.02786223]
#  [0.028896  ]
#  [0.02809178]
#  [0.02315103]
#  [0.0277679 ]
#  [0.02787967]
#  [0.02806645]
#  [0.02262221]
#  [0.02838402]
#  [0.02808618]
#  [0.02810766]
#  [0.02256079]
#  [0.02809963]
#  [0.02852939]
#  [0.02776959]
#  [0.02284008]
#  [0.02268641]
#  [0.02782727]]
# loss vector of epoc 100 is
# [[0.00039936]
#  [0.00026533]
#  [0.00025641]
#  [0.00026349]
#  [0.00041117]
#  [0.00026529]
#  [0.00038644]
#  [0.00038441]
#  [0.0002547 ]
#  [0.00039806]
#  [0.00040409]
#  [0.00026028]
#  [0.00025888]
#  [0.00038873]
#  [0.00025677]
#  [0.00027089]
#  [0.000385  ]
#  [0.00025787]
#  [0.00038873]
#  [0.00040858]
#  [0.0003898 ]
#  [0.00026278]
#  [0.00038815]
#  [0.00041749]
#  [0.00039457]
#  [0.00026799]
#  [0.00038553]
#  [0.00038864]
#  [0.00039386]
#  [0.00025588]
#  [0.00040283]
#  [0.00039442]
#  [0.00039502]
#  [0.00025449]
#  [0.00039479]
#  [0.00040696]
#  [0.00038558]
#  [0.00026083]
#  [0.00025734]
#  [0.00038718]]
# Mean loss of epoc 100 is
# 0.00034121534056899615
# Total loss of epoc 100 is
# 0.013648613622759846

# %%
[x] = results[2].transpose().tolist()

# %%
con = pd.DataFrame({'guess':x, 'actual':y_train})
con['guess_com'] = con.apply(lambda row: 1 if row.guess >= .5 else 0, axis = 1)

# %%
confusion_matrix(con['actual'],con['guess_com'])
# Out:
# array([[40]])
